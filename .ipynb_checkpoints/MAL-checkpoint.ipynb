# %%
###Run this code to create a JSON file that diables auto-quotes and auto-brackets. After executing the Python 
#command, or manually creating the file, restart your Jupyter notebook, and it should stop auto-closing quotes
#and brackets.

#from notebook.services.config import ConfigManager
#c = ConfigManager()
#c.update('notebook', {"CodeCell": {"cm_config": {"autoCloseBrackets": False}}})

###Keyboard Shortcuts
#Ctrl + Enter: Run single cell of code (similar to R)
#Ctrl + Shift + Enter: Reun entire notebook (similar to R)

# %%
#Intro to Web Scraping and BeautifulSoup
#https://www.youtube.com/watch?v=XQgXKtPSzUI

#exporting to excel
#df.to_excel("check.xlsx")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
#import re #for splitting strings using multiple delimiters
import time
import random

premiers = []
genres = []
scores = []

# %%
df0 = pd.read_excel('list.xlsx')

#Removing unnecessary extra columns
columns = [11,14,19,21,23,25,26]
df = df0.iloc[:,columns]

#Renaming column names
df = df.rename(columns={'/anime/my_score':'myscore','/anime/my_status':'status','/anime/my_watched_episodes':'watched', \
                        '/anime/series_animedb_id':'id','/anime/series_episodes':'episodes', \
                        '/anime/series_title':'title','/anime/series_type':'type'})
df
# Out:
#      myscore         status  watched     id  episodes  \
# 0          7      Completed       12  38101        12
# 1          5      Completed       12  36039        12
# 2          8      Completed       10  36904        10
# 3          8      Completed       10  37985        10
# 4          0  Plan to Watch        0  40215         0
# ..       ...            ...      ...    ...       ...
# 260        0  Plan to Watch        0  35507        12
# 261        0        Dropped        4  18677        12
# 262        7      Completed       12  34176        12
# 263        8      Completed       12  37976        12
# 264        0  Plan to Watch        0  40174         0
#
#                                                  title type
# 0                                 5-toubun no Hanayome   TV
# 1                                A.I.C.O.: Incarnation  ONA
# 2                             Aggressive Retsuko (ONA)  ONA
# 3                  Aggressive Retsuko (ONA) 2nd Season  ONA
# 4                  Aggressive Retsuko (ONA) 3rd Season  ONA
# ..                                                 ...  ...
# 260  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...   TV
# 261  Yuusha ni Narenakatta Ore wa Shibushibu Shuush...   TV
# 262                    Zero kara Hajimeru Mahou no Sho   TV
# 263                                    Zombieland Saga   TV
# 264                           Zombieland Saga: Revenge   TV
#
# [265 rows x 7 columns]

# %%
"""
#Creating complete df

#Open pages to scrape more data about shows
for i in range(len(df)): #number of rows of df
    #wait random time between 0-5 seconds before scraping data
    r = random.randint(0,5)
    time.sleep(r)

    URL = 'https://myanimelist.net/anime/%d/' % df.loc[i,'id']
    page = urlopen(URL)
    soup = BeautifulSoup(page,'html.parser')
    #finding all span-dark_text containers i.e. bolded text on left
    containers = soup.findAll('span',attrs={'class':'dark_text'})

    
    ####Getting container indecies
    #'Premiered' for type TV, 'Aired' for non-TV types
    if df.loc[i,'type'] == 'TV':
        keyword = 'Premiered'
        #outputs of this form 'Premiered:\nFall 2017'
        omit_start = 11 #omitting 'Premiered:\n'
    else:
        keyword = 'Aired'
        #outputs of this form 'Aired:\n Dec 10, 2005'
        omit_start = 9 #omitting 'Premiered:\n '

    #Extracts title texts and looks for index_container for Premiered or Aired
    for t in range(len(containers)):
        if keyword in containers[t].text:
            index_container_premiered = t
            break #breaks out of t loop once index found
        if t == len(containers):
            #if no index found 
            print('No index for index_container_premiered')
               
    #Extracts title texts and looks for index_container for Genre
    for t in range(len(containers)):
        if 'Genres' in containers[t].text:
            index_container_genre = t
            break #breaks out of t loop once index found
        if t == len(containers):
            #if no index found 
            print('No index for index_container_genre')

    #Extracts title texts and looks for index_container for Score
    for t in range(len(containers)):
        if 'Score' in containers[t].text:
            index_container_score = t
            break #breaks out of t loop once index found
        if t == len(containers):
            #if no index found 
            print('No index for index_container_score')
            
    ####Looks at parent object for easy access to div container much easier than findAll('div')
    premier = containers[index_container_premiered].parent.text.strip() #outputs of this form: see above
    premier = premier[omit_start:] #omitting see above
    premiers = premiers + [premier]

    container_parent = containers[index_container_genre].parent
    list_genres = container_parent.findAll('span')
    genre = []
    for g in list_genres[1:]: #exlcuding the first span object, which is the text 'Genres:'
        genre = genre + [g.text]
    genres = genres + [genre]

    score = containers[index_container_score].parent.text.strip() #outputs of this form: see above
    score = score[7:12] #only extracting float X.XXX
    scores = scores + [score]
    
    
df['premiered'] = premiers
df['genres'] = genres
df['score'] = scores
df
#df.to_excel("df.xlsx")
"""

# %%
#Converting Exported df back into correct format
df = pd.read_excel('df.xlsx')
df = df.drop(columns='Unnamed: 0') #removing column of indecies

#When exporting, genres entries got converted from list type to string
#Converting string representation of list to list type
import ast
genres = []
for i in range(len(df)):
    ini_list = df.loc[i,'genres']
    res = ast.literal_eval(ini_list) # Converting string to list 
    genres = genres + [res]
df['genres'] = genres
#df['score'] = scores

df
# Out:
#      myscore         status  watched     id  episodes  \
# 0          7      Completed       12  38101        12
# 1          5      Completed       12  36039        12
# 2          8      Completed       10  36904        10
# 3          8      Completed       10  37985        10
# 4          0  Plan to Watch        0  40215         0
# ..       ...            ...      ...    ...       ...
# 260        0  Plan to Watch        0  35507        12
# 261        0        Dropped        4  18677        12
# 262        7      Completed       12  34176        12
# 263        8      Completed       12  37976        12
# 264        0  Plan to Watch        0  40174         0
#
#                                                  title type      premiered  \
# 0                                 5-toubun no Hanayome   TV    Winter 2019
# 1                                A.I.C.O.: Incarnation  ONA    Mar 9, 2018
# 2                             Aggressive Retsuko (ONA)  ONA   Apr 20, 2018
# 3                  Aggressive Retsuko (ONA) 2nd Season  ONA   Jun 14, 2019
# 4                  Aggressive Retsuko (ONA) 3rd Season  ONA  Not available
# ..                                                 ...  ...            ...
# 260  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...   TV    Summer 2017
# 261  Yuusha ni Narenakatta Ore wa Shibushibu Shuush...   TV      Fall 2013
# 262                    Zero kara Hajimeru Mahou no Sho   TV    Spring 2017
# 263                                    Zombieland Saga   TV      Fall 2018
# 264                           Zombieland Saga: Revenge   TV              ?
#
#                                             genres  score
# 0        [Harem, Comedy, Romance, School, Shounen]  7.641
# 1                                 [Action, Sci-Fi]  6.771
# 2                          [Slice of Life, Comedy]  7.791
# 3                          [Slice of Life, Comedy]  7.871
# 4                          [Comedy, Slice of Life]  N/A1
# ..                                             ...    ...
# 260  [Slice of Life, Psychological, Drama, School]  7.911
# 261              [Comedy, Romance, Ecchi, Fantasy]  6.991
# 262            [Action, Adventure, Magic, Fantasy]  7.171
# 263                  [Comedy, Music, Supernatural]  7.641
# 264                  [Music, Comedy, Supernatural]  N/A1
#
# [265 rows x 10 columns]

# %%
#df subset - Only looking at scored series
DFA = df.loc[df['myscore'] > 0]
DFA = DFA.reset_index(drop=True) #reset df indecies
DFA
# Out:
#      myscore     status  watched     id  episodes  \
# 0          7  Completed       12  38101        12
# 1          5  Completed       12  36039        12
# 2          8  Completed       10  36904        10
# 3          8  Completed       10  37985        10
# 4          8  Completed        1  38815         1
# ..       ...        ...      ...    ...       ...
# 171        8  Completed       12  37779        12
# 172        8  Completed       12  32615        12
# 173        8  Completed        1  37055         1
# 174        7  Completed       12  34176        12
# 175        8  Completed       12  37976        12
#
#                                                  title   type     premiered  \
# 0                                 5-toubun no Hanayome     TV   Winter 2019
# 1                                A.I.C.O.: Incarnation    ONA   Mar 9, 2018
# 2                             Aggressive Retsuko (ONA)    ONA  Apr 20, 2018
# 3                  Aggressive Retsuko (ONA) 2nd Season    ONA  Jun 14, 2019
# 4    Aggressive Retsuko: We Wish You a Metal Christmas    ONA  Dec 20, 2018
# ..                                                 ...    ...           ...
# 171                              Yakusoku no Neverland     TV   Winter 2019
# 172                                        Youjo Senki     TV   Winter 2017
# 173                                  Youjo Senki Movie  Movie   Feb 8, 2019
# 174                    Zero kara Hajimeru Mahou no Sho     TV   Spring 2017
# 175                                    Zombieland Saga     TV     Fall 2018
#
#                                                 genres  score
# 0            [Harem, Comedy, Romance, School, Shounen]  7.641
# 1                                     [Action, Sci-Fi]  6.771
# 2                              [Slice of Life, Comedy]  7.791
# 3                              [Slice of Life, Comedy]  7.871
# 4                              [Slice of Life, Comedy]  7.341
# ..                                                 ...    ...
# 171  [Sci-Fi, Mystery, Horror, Psychological, Thril...  8.691
# 172                          [Action, Military, Magic]  8.091
# 173                          [Action, Magic, Military]  8.391
# 174                [Action, Adventure, Magic, Fantasy]  7.171
# 175                      [Comedy, Music, Supernatural]  7.641
#
# [176 rows x 10 columns]

# %%
#MyScore distribution
a = DFA.loc[:,'myscore']
b = plt.hist(a,bins=range(1,11))

print('MyScore Mean: %.3f' % np.mean(a))
print('MyScore St. Dev.: %.3f' % np.std(a))
# Out:
# MyScore Mean: 7.631
# MyScore St. Dev.: 0.926

# %%
#testing cell

import ast
genres = []
for i in range(len(df)):
    ini_list = df.loc[i,'genres']
    res = ast.literal_eval(ini_list) # Converting string to list 
    genres = genres + [res]
df['genres'] = genres
# Out:
#      myscore         status  watched     id  episodes  \
# 0          7      Completed       12  38101        12
# 1          5      Completed       12  36039        12
# 2          8      Completed       10  36904        10
# 3          8      Completed       10  37985        10
# 4          0  Plan to Watch        0  40215         0
# ..       ...            ...      ...    ...       ...
# 260        0  Plan to Watch        0  35507        12
# 261        0        Dropped        4  18677        12
# 262        7      Completed       12  34176        12
# 263        8      Completed       12  37976        12
# 264        0  Plan to Watch        0  40174         0
#
#                                                  title type      premiered  \
# 0                                 5-toubun no Hanayome   TV    Winter 2019
# 1                                A.I.C.O.: Incarnation  ONA    Mar 9, 2018
# 2                             Aggressive Retsuko (ONA)  ONA   Apr 20, 2018
# 3                  Aggressive Retsuko (ONA) 2nd Season  ONA   Jun 14, 2019
# 4                  Aggressive Retsuko (ONA) 3rd Season  ONA  Not available
# ..                                                 ...  ...            ...
# 260  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...   TV    Summer 2017
# 261  Yuusha ni Narenakatta Ore wa Shibushibu Shuush...   TV      Fall 2013
# 262                    Zero kara Hajimeru Mahou no Sho   TV    Spring 2017
# 263                                    Zombieland Saga   TV      Fall 2018
# 264                           Zombieland Saga: Revenge   TV              ?
#
#                                             genres  score
# 0        [Harem, Comedy, Romance, School, Shounen]  7.641
# 1                                 [Action, Sci-Fi]  6.771
# 2                          [Slice of Life, Comedy]  7.791
# 3                          [Slice of Life, Comedy]  7.871
# 4                          [Comedy, Slice of Life]  N/A1
# ..                                             ...    ...
# 260  [Slice of Life, Psychological, Drama, School]  7.911
# 261              [Comedy, Romance, Ecchi, Fantasy]  6.991
# 262            [Action, Adventure, Magic, Fantasy]  7.171
# 263                  [Comedy, Music, Supernatural]  7.641
# 264                  [Music, Comedy, Supernatural]  N/A1
#
# [265 rows x 10 columns]

# %%
a = [1,np.nan,2,3,np.nan,120384]
type(a)
df.loc[263,'score']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-359-31656d74df78> in <module>
#       1 a = [1,np.nan,2,3,np.nan,120384]
#       2 type(a)
# ----> 3 df.loc[263,'score'] + 256
#
# TypeError: can only concatenate str (not "int") to str
